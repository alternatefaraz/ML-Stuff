# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\fashraf\Documents\fdata.csv', sep=',', parse_dates=True, index_col=0)
df.plot()
plt.show()

# %%
df = df.reset_index()
df
# Out:
#    index       Date        Open        High         Low       Close
# 0      0 2016-10-03  774.250000  776.065002  769.500000  772.559998
# 1      1 2016-10-04  776.030029  778.710022  772.890015  776.429993
# 2      2 2016-10-05  779.309998  782.070007  775.650024  776.469971
# 3      3 2016-10-06  779.000000  780.479980  775.539978  776.859985
# 4      4 2016-10-07  779.659973  779.659973  770.750000  775.080017

# %%
df.set_index('Date', inplace=True, drop=False)

# %%
dfClose = df.loc[:, ['Close']]
dfClose = dfClose.reset_index()
dfClose
# Out:
#         Date       Close
# 0 2016-10-03  772.559998
# 1 2016-10-04  776.429993
# 2 2016-10-05  776.469971
# 3 2016-10-06  776.859985
# 4 2016-10-07  775.080017

# %%
df[['Date','Close']].plot('Date', figsize=(15,8))
plt.grid()
plt.show()
